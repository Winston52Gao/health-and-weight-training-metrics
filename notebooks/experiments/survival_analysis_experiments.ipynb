# %% [markdown]
# # Survival Analysis Experiments
# Use this notebook for exploratory survival diagnostics and research-only experiments.
# Production deployment uses workout-only Model C scripts under scripts/.

# %%
import json
from pathlib import Path

summary_path = Path('reports/model_C_ablation_summary.json')
if summary_path.exists():
    print(json.dumps(json.loads(summary_path.read_text()), indent=2))
else:
    print('No ablation summary found yet.')
